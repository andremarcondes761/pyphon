# %% [markdown]
# <a href="https://colab.research.google.com/github/andremarcondes761/pyphon/blob/main/pyphon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **aula 1 ** ☢ ⚓ ☯
# ![image.png](data:image/png;base64,...)

# %%
ano = "IX"
print(ano, "competição de programação dá Start")
# Out:
# IX competição de programação dá Start

# %% [markdown]
# **aula2** ◀ ⚓ ▶

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2* livro_ficcao + 5* livro_infantil
pontos_totais = pontos_ana + pontos_rodrigo
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais de ana são {pontos_ana}")
print(f"Os pontos totais do Robrigo e ana são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais de ana são 46
# Os pontos totais do Robrigo e ana são 70

# %% [markdown]
# **Aula 3** ✈ ⏰ #

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
figurinhas_joao = 2 * figurinhas_amigo

print(f"João recebeu {figurinhas_joao} figurinhas")
# Out:
# Digite o total de figurinhas: 41
# Digite o número de amigos: 2
# João recebeu 20 figurinhas

# %% [markdown]
# **Aula 4** * ☹ ♋

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 11
# 11 x 1 = 11
# 11 x 2 = 22
# 11 x 3 = 33
# 11 x 4 = 44
# 11 x 5 = 55
# 11 x 6 = 66
# 11 x 7 = 77
# 11 x 8 = 88
# 11 x 9 = 99
# 11 x 10 = 110

# %% [markdown]
# **Aula 5 ** ♈ ⁉ ☣

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} / {contador} = {numero // contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)

# %% [markdown]
# **Aula 6** chatbot♑ 🖖 ❌

# %%
print("Olá, sou seu assistente virtual")
nome = input("Digite seu nome")
print(f"Olá {nome}, em que poso ajudar")
# Out:
# Olá, sou seu assistente virtual

# %%
print("olá, sou o seu assistente virtual")
nome = input("Digite seu nome")
print(f"olá {nome}, em que posso ajudar")
resposta = input("você deseja falar sobre python, javascript ou matematica: ").lower()
if resposta =="python":
  print("Ótimo, vamos falar sobre Python!")
elif resposta=="javascript":
  print(f"Ótimo, {nome}, vamos falar sobre Python!")
elif resposta=="matematica":
  print(f"Ótimo, {nome}, vamos falar sobre matematica!")
  else:
     print(f"que pena, {nome}, não se falar sobre esse asunto!")
